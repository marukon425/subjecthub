# %% [markdown]
# # Pillowの練習
# https://note.nkmk.me/pillow/

# %% [markdown]
# ## 画像のオープン、表示

# %% [markdown]
# Image.open(画像ファイル名)
# 画像オブジェクト.show()

# %% [markdown]
# 問 'target.jpg'を開いて表示してください

# %%
# Imageのインポート


# 画像ファイルのオープン ... 画像オブジェクトの生成
image_in =

# 画像の表示

# %% [markdown]
# ## サイズの取得

# %% [markdown]
# 画像オブジェクト.size ... 幅と高さ
# 画像オブジェクト.width ... 幅
# 画像オブジェクト.height ... 高さ

# %% [markdown]
# 問 サイズ、幅、高さを表示してください

# %%
# サイズ(幅と高さ)

# %%
# 幅

# %%
# 高さ

# %% [markdown]
# ## 新規画像の作成

# %% [markdown]
# Image.new('RGB', サイズ, 色)
# サイズ:(幅, 高さ)
# 色:(赤, 緑, 青)

# %% [markdown]
# 問 幅400px、高さ200px、色がR:230、G:230、B:230の画像を作成してください

# %%
# Imageのインポート


# 画像の新規作成
image_new =

# 画像を表示

# %% [markdown]
# ## 部分切り抜き
# https://note.nkmk.me/python-pillow-image-crop-trimming/

# %% [markdown]
# 画像"target.jpg"から次の範囲を切り抜いて表示してください
# 左:100、上:200、右:400、下:700

# %%
# 画像ファイルのオープン ... 画像オブジェクトの生成
image_in =

# 切り抜き
image_crop =

# 画像を表示

# %% [markdown]
# ## リサイズ
# https://note.nkmk.me/python-pillow-image-resize/

# %% [markdown]
# 問 画像"target.jpg"を幅256px、高さ256pxにリサイズし、表示してください

# %%
# 画像ファイルのオープン ... 画像オブジェクトの生成
image_in =

# リサイズ
image_resize =

# 画像を表示

# %% [markdown]
# 問 画像"target"の幅と高さの縦横比を保ったまま0.3倍にリサイズし、表示してください

# %%
# 画像ファイルのオープン ... 画像オブジェクトの生成


# リサイズ


# 画像を表示

# %% [markdown]
# ## 線の描画
# https://note.nkmk.me/python-pillow-imagedraw/

# %% [markdown]
# 問 新規画像を作成し、画像の範囲内に線を描画してください
# 線について
# ・開始x:100、開始y:50、終了x:200、終了y:100
# ・塗りつぶしの色R:255、G:0、B:0
# ・線の太さ:10

# %%
# Image、ImageDrawのインポート



# 画像の新規作成
image_new = Image.new('RGB', (400, 200), (230, 230, 230))

# 画像オブジェクトに対する描画オブジェクトの生成
draw =

# 線の描画


# 画像を表示(描画された状態になっている)

# %% [markdown]
# 問 画像"target.jpg"を開き、画像の範囲内に線を描画してください
# 線について
# ・開始x:100、開始y:50、終了x:200、終了y:100
# ・塗りつぶしの色R:255、G:0、B:0
# ・線の太さ:10

# %%
# Image、ImageDrawのインポート



# すでにある画像に対しても描画できる
# 画像ファイルのオープン ... 画像オブジェクトの生成
image_in = Image.open('target.jpg')

# 画像オブジェクトに対する描画オブジェクトの生成
draw =

# 線の描画


# 画像を表示(描画された状態になっている)

# %% [markdown]
# ## テキストの描画
# https://note.nkmk.me/python-pillow-imagedraw-text-imagefont/

# %% [markdown]
# 問 画像"target.jpg"を開き、画像の範囲内にテキストを描画してください
# テキストについて
# ・横:100、高さ:20
# ・テキスト:Test
# ・塗りつぶしの色R:0、G:0、B:255

# %%
# Image、ImageDrawのインポート


# 画像ファイルのオープン ... 画像オブジェクトの生成
image_in = Image.open('target.jpg')

# 画像オブジェクトに対する描画オブジェクトの生成
draw =

# 文字の描画


# 画像を表示(描画された状態になっている)
