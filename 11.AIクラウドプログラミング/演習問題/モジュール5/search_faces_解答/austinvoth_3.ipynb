# %%
#必要なモジュールのインポート
import boto3 # AWSのサービスを利用するときに必須
import json # json形式のデータを処理する
from PIL import Image # pillow の Image モジュール 画像処理に使用する

# %%
# コレクションIDを入力
collection_id = input("文字列を入力してください:")
# Out:
# 文字列を入力してください: MyCollection

# %% [markdown]
# # サービスクライアントを作成

# %%
rekognition = boto3.client('rekognition')

# %% [markdown]
# # コレクションの作成

# %%
# コレクションを作成する
result = rekognition.create_collection(CollectionId=collection_id)

# 結果のjsonを整形して表示
print(json.dumps(result, indent=4))
# Out:
# {
#     "StatusCode": 200,
#     "CollectionArn": "aws:rekognition:us-east-1:546943788404:collection/MyCollection",
#     "FaceModelVersion": "7.0",
#     "ResponseMetadata": {
#         "RequestId": "fde43b83-aee0-4d81-931d-80aaebeaed37",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "x-amzn-requestid": "fde43b83-aee0-4d81-931d-80aaebeaed37",
#             "content-type": "application/x-amz-json-1.1",
#             "content-length": "124",
#             "date": "Fri, 06 Mar 2026 08:00:12 GMT"
#         },
#         "RetryAttempts": 0
#     }
# }

# %% [markdown]
# # コレクションの表示

# %%
print('コレクションの一覧')
# コレクションの一覧を取得
result = rekognition.list_collections()

# 結果のjsonを整形して表示
print(json.dumps(result, indent=4))

print('登録されている顔の一覧')
# 登録された顔の一覧を取得
result = rekognition.list_faces(CollectionId=collection_id)
# 登録された顔の一覧を表示
print(json.dumps(result, indent=4))
# Out:
# コレクションの一覧
# {
#     "CollectionIds": [
#         "MyCollection",
#         "demo120402-mashiko"
#     ],
#     "FaceModelVersions": [
#         "7.0",
#         "7.0"
#     ],
#     "ResponseMetadata": {
#         "RequestId": "068eb1a5-48f5-48a0-91ca-bce738c31fbb",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "x-amzn-requestid": "068eb1a5-48f5-48a0-91ca-bce738c31fbb",
#             "content-type": "application/x-amz-json-1.1",
#             "content-length": "89",
#             "date": "Fri, 06 Mar 2026 08:00:13 GMT"
#         },
#         "RetryAttempts": 0
#     }
# }
# 登録されている顔の一覧
# {
#     "Faces": [],
#     "FaceModelVersion": "7.0",
#     "ResponseMetadata": {
#         "RequestId": "e308b728-350b-4d42-9e8a-25456ba70058",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "x-amzn-requestid": "e308b728-350b-4d42-9e8a-25456ba70058",
#             "content-type": "application/x-amz-json-1.1",
#             "content-length": "37",
#             "date": "Fri, 06 Mar 2026 08:00:13 GMT"
#         },
#         "RetryAttempts": 0
#     }
# }

# %% [markdown]
# # コレクションに顔を登録する

# %%
# 登録する画像のリスト
# images_regist = ['richard.jpg', 'richard2.jpg']


# ユーザーに画像ファイル名を入力させる（カンマ区切り）
input_files = input("登録したい画像ファイル名をカンマ区切りで入力してください: ")
 
# 入力をリストに変換（空白を除去）
images_regist = [f.strip() for f in input_files.split(',')]
 
print("登録する画像:", images_regist)
# Out:
# 登録したい画像ファイル名をカンマ区切りで入力してください:  sharing_01.jpg
# 登録する画像: ['sharing_01.jpg']

# %%
# 顔の登録
print('index_faces:')
print(len(images_regist))

# 指定された画像ファイルの分だけ繰り返す
for path in images_regist:
    # 画像ファイルをオープン
    with open(path, 'rb') as file:
        # 画像内の顔を登録
        result = rekognition.index_faces(
            CollectionId=collection_id,
            Image={'Bytes': file.read()})

    # 顔の登録結果を表示
    print(json.dumps(result, indent=4))
# Out:
# index_faces:
# 1
# {
#     "FaceRecords": [
#         {
#             "Face": {
#                 "FaceId": "ad749a7f-e07c-48ed-b114-47fe81c15ece",
#                 "BoundingBox": {
#                     "Width": 0.049764346331357956,
#                     "Height": 0.1336122453212738,
#                     "Left": 0.7468746304512024,
#                     "Top": 0.22909905016422272
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.99463653564453
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.049764346331357956,
#                     "Height": 0.1336122453212738,
#                     "Left": 0.7468746304512024,
#                     "Top": 0.22909905016422272
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.7580944299697876,
#                         "Y": 0.282715767621994
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.7802215814590454,
#                         "Y": 0.2815800905227661
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.7607644200325012,
#                         "Y": 0.3267151415348053
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.7792198657989502,
#                         "Y": 0.3258369266986847
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.767606258392334,
#                         "Y": 0.3054196536540985
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": -2.964634895324707,
#                     "Yaw": -7.261559009552002,
#                     "Pitch": 5.254802703857422
#                 },
#                 "Quality": {
#                     "Brightness": 96.86333465576172,
#                     "Sharpness": 38.89601135253906
#                 },
#                 "Confidence": 99.99463653564453
#             }
#         },
#         {
#             "Face": {
#                 "FaceId": "c93758bd-eff7-48be-a308-639112b8f497",
#                 "BoundingBox": {
#                     "Width": 0.05072343349456787,
#                     "Height": 0.13088032603263855,
#                     "Left": 0.138006329536438,
#                     "Top": 0.24108120799064636
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.98201751708984
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.05072343349456787,
#                     "Height": 0.13088032603263855,
#                     "Left": 0.138006329536438,
#                     "Top": 0.24108120799064636
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.1511065661907196,
#                         "Y": 0.2898484170436859
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.17331577837467194,
#                         "Y": 0.2938302755355835
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.15104776620864868,
#                         "Y": 0.33478859066963196
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.16955848038196564,
#                         "Y": 0.3380756974220276
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.16134755313396454,
#                         "Y": 0.31493791937828064
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": 3.8849189281463623,
#                     "Yaw": -0.05406352877616882,
#                     "Pitch": 5.077417850494385
#                 },
#                 "Quality": {
#                     "Brightness": 97.05419921875,
#                     "Sharpness": 38.89601135253906
#                 },
#                 "Confidence": 99.98201751708984
#             }
#         },
#         {
#             "Face": {
#                 "FaceId": "3cb5027d-3a99-4bac-82d0-66c77f2b460f",
#                 "BoundingBox": {
#                     "Width": 0.0519225113093853,
#                     "Height": 0.12776799499988556,
#                     "Left": 0.42692357301712036,
#                     "Top": 0.23608079552650452
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.9924545288086
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.0519225113093853,
#                     "Height": 0.12776799499988556,
#                     "Left": 0.42692357301712036,
#                     "Top": 0.23608079552650452
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.4402942657470703,
#                         "Y": 0.2865462601184845
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.46262311935424805,
#                         "Y": 0.2861235439777374
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.4423616826534271,
#                         "Y": 0.3310335874557495
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.4609658718109131,
#                         "Y": 0.3306967318058014
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.45049405097961426,
#                         "Y": 0.30841097235679626
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": -1.2351263761520386,
#                     "Yaw": -2.7205824851989746,
#                     "Pitch": 7.740494251251221
#                 },
#                 "Quality": {
#                     "Brightness": 97.19377136230469,
#                     "Sharpness": 38.89601135253906
#                 },
#                 "Confidence": 99.9924545288086
#             }
#         },
#         {
#             "Face": {
#                 "FaceId": "f21f1e00-5046-4fd2-b457-4416576d8b65",
#                 "BoundingBox": {
#                     "Width": 0.04584326595067978,
#                     "Height": 0.11522972583770752,
#                     "Left": 0.2906266152858734,
#                     "Top": 0.31464070081710815
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.96316528320312
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.04584326595067978,
#                     "Height": 0.11522972583770752,
#                     "Left": 0.2906266152858734,
#                     "Top": 0.31464070081710815
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.30469584465026855,
#                         "Y": 0.35756850242614746
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.32500728964805603,
#                         "Y": 0.35811904072761536
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.3059970736503601,
#                         "Y": 0.3982810080051422
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.3229619264602661,
#                         "Y": 0.3986775875091553
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.3162679672241211,
#                         "Y": 0.379190593957901
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": 2.1261088848114014,
#                     "Yaw": 6.4102654457092285,
#                     "Pitch": 4.2645134925842285
#                 },
#                 "Quality": {
#                     "Brightness": 94.47605895996094,
#                     "Sharpness": 32.20803451538086
#                 },
#                 "Confidence": 99.96316528320312
#             }
#         },
#         {
#             "Face": {
#                 "FaceId": "ff8f2293-b3c5-451e-907e-26bf41c3220d",
#                 "BoundingBox": {
#                     "Width": 0.04578866809606552,
#                     "Height": 0.11016335338354111,
#                     "Left": 0.5914050340652466,
#                     "Top": 0.3369940519332886
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.9622802734375
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.04578866809606552,
#                     "Height": 0.11016335338354111,
#                     "Left": 0.5914050340652466,
#                     "Top": 0.3369940519332886
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.6017645597457886,
#                         "Y": 0.37588173151016235
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.6220445036888123,
#                         "Y": 0.3772217631340027
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.6031726002693176,
#                         "Y": 0.41564491391181946
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.6201534271240234,
#                         "Y": 0.41684505343437195
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.6099854707717896,
#                         "Y": 0.3986069858074188
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": 1.4495017528533936,
#                     "Yaw": -6.403176307678223,
#                     "Pitch": -0.1564931571483612
#                 },
#                 "Quality": {
#                     "Brightness": 91.34667205810547,
#                     "Sharpness": 20.927310943603516
#                 },
#                 "Confidence": 99.9622802734375
#             }
#         }
#     ],
#     "FaceModelVersion": "7.0",
#     "UnindexedFaces": [],
#     "ResponseMetadata": {
#         "RequestId": "275c3a01-cae8-481a-9445-2562b4fa3393",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "x-amzn-requestid": "275c3a01-cae8-481a-9445-2562b4fa3393",
#             "content-type": "application/x-amz-json-1.1",
#             "content-length": "4752",
#             "date": "Fri, 06 Mar 2026 08:00:29 GMT"
#         },
#         "RetryAttempts": 0
#     }
# }

# %% [markdown]
# # 画像に写っている顔が、コレクションの中に存在するかをチェック

# %%
file_in = 'sharing_01.jpg' # コレクションに存在するかチェックする画像
file_out = 'detected.jpg' # 見つかった顔の部分だけを出力する画像ファイル名
# 画像ファイルを開く
with open(file_in, 'rb') as file:
    # 画像内の顔をコレクションから探す
    result = rekognition.index_faces(
        CollectionId=collection_id,
        Image={'Bytes': file.read()})
# 結果を整形して表示
print(json.dumps(result, indent=4))
# Out:
# {
#     "FaceRecords": [
#         {
#             "Face": {
#                 "FaceId": "ad749a7f-e07c-48ed-b114-47fe81c15ece",
#                 "BoundingBox": {
#                     "Width": 0.049764346331357956,
#                     "Height": 0.1336122453212738,
#                     "Left": 0.7468746304512024,
#                     "Top": 0.22909905016422272
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.99463653564453
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.049764346331357956,
#                     "Height": 0.1336122453212738,
#                     "Left": 0.7468746304512024,
#                     "Top": 0.22909905016422272
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.7580944299697876,
#                         "Y": 0.282715767621994
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.7802215814590454,
#                         "Y": 0.2815800905227661
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.7607644200325012,
#                         "Y": 0.3267151415348053
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.7792198657989502,
#                         "Y": 0.3258369266986847
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.767606258392334,
#                         "Y": 0.3054196536540985
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": -2.964634895324707,
#                     "Yaw": -7.261559009552002,
#                     "Pitch": 5.254802703857422
#                 },
#                 "Quality": {
#                     "Brightness": 96.86333465576172,
#                     "Sharpness": 38.89601135253906
#                 },
#                 "Confidence": 99.99463653564453
#             }
#         },
#         {
#             "Face": {
#                 "FaceId": "c93758bd-eff7-48be-a308-639112b8f497",
#                 "BoundingBox": {
#                     "Width": 0.05072343349456787,
#                     "Height": 0.13088032603263855,
#                     "Left": 0.138006329536438,
#                     "Top": 0.24108120799064636
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.98201751708984
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.05072343349456787,
#                     "Height": 0.13088032603263855,
#                     "Left": 0.138006329536438,
#                     "Top": 0.24108120799064636
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.1511065661907196,
#                         "Y": 0.2898484170436859
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.17331577837467194,
#                         "Y": 0.2938302755355835
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.15104776620864868,
#                         "Y": 0.33478859066963196
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.16955848038196564,
#                         "Y": 0.3380756974220276
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.16134755313396454,
#                         "Y": 0.31493791937828064
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": 3.8849189281463623,
#                     "Yaw": -0.05406352877616882,
#                     "Pitch": 5.077417850494385
#                 },
#                 "Quality": {
#                     "Brightness": 97.05419921875,
#                     "Sharpness": 38.89601135253906
#                 },
#                 "Confidence": 99.98201751708984
#             }
#         },
#         {
#             "Face": {
#                 "FaceId": "3cb5027d-3a99-4bac-82d0-66c77f2b460f",
#                 "BoundingBox": {
#                     "Width": 0.0519225113093853,
#                     "Height": 0.12776799499988556,
#                     "Left": 0.42692357301712036,
#                     "Top": 0.23608079552650452
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.9924545288086
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.0519225113093853,
#                     "Height": 0.12776799499988556,
#                     "Left": 0.42692357301712036,
#                     "Top": 0.23608079552650452
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.4402942657470703,
#                         "Y": 0.2865462601184845
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.46262311935424805,
#                         "Y": 0.2861235439777374
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.4423616826534271,
#                         "Y": 0.3310335874557495
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.4609658718109131,
#                         "Y": 0.3306967318058014
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.45049405097961426,
#                         "Y": 0.30841097235679626
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": -1.2351263761520386,
#                     "Yaw": -2.7205824851989746,
#                     "Pitch": 7.740494251251221
#                 },
#                 "Quality": {
#                     "Brightness": 97.19377136230469,
#                     "Sharpness": 38.89601135253906
#                 },
#                 "Confidence": 99.9924545288086
#             }
#         },
#         {
#             "Face": {
#                 "FaceId": "f21f1e00-5046-4fd2-b457-4416576d8b65",
#                 "BoundingBox": {
#                     "Width": 0.04584326595067978,
#                     "Height": 0.11522972583770752,
#                     "Left": 0.2906266152858734,
#                     "Top": 0.31464070081710815
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.96316528320312
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.04584326595067978,
#                     "Height": 0.11522972583770752,
#                     "Left": 0.2906266152858734,
#                     "Top": 0.31464070081710815
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.30469584465026855,
#                         "Y": 0.35756850242614746
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.32500728964805603,
#                         "Y": 0.35811904072761536
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.3059970736503601,
#                         "Y": 0.3982810080051422
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.3229619264602661,
#                         "Y": 0.3986775875091553
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.3162679672241211,
#                         "Y": 0.379190593957901
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": 2.1261088848114014,
#                     "Yaw": 6.4102654457092285,
#                     "Pitch": 4.2645134925842285
#                 },
#                 "Quality": {
#                     "Brightness": 94.47605895996094,
#                     "Sharpness": 32.20803451538086
#                 },
#                 "Confidence": 99.96316528320312
#             }
#         },
#         {
#             "Face": {
#                 "FaceId": "ff8f2293-b3c5-451e-907e-26bf41c3220d",
#                 "BoundingBox": {
#                     "Width": 0.04578866809606552,
#                     "Height": 0.11016335338354111,
#                     "Left": 0.5914050340652466,
#                     "Top": 0.3369940519332886
#                 },
#                 "ImageId": "c0da4c11-9dc5-3192-8d3a-7132cfa488fa",
#                 "Confidence": 99.9622802734375
#             },
#             "FaceDetail": {
#                 "BoundingBox": {
#                     "Width": 0.04578866809606552,
#                     "Height": 0.11016335338354111,
#                     "Left": 0.5914050340652466,
#                     "Top": 0.3369940519332886
#                 },
#                 "Landmarks": [
#                     {
#                         "Type": "eyeLeft",
#                         "X": 0.6017645597457886,
#                         "Y": 0.37588173151016235
#                     },
#                     {
#                         "Type": "eyeRight",
#                         "X": 0.6220445036888123,
#                         "Y": 0.3772217631340027
#                     },
#                     {
#                         "Type": "mouthLeft",
#                         "X": 0.6031726002693176,
#                         "Y": 0.41564491391181946
#                     },
#                     {
#                         "Type": "mouthRight",
#                         "X": 0.6201534271240234,
#                         "Y": 0.41684505343437195
#                     },
#                     {
#                         "Type": "nose",
#                         "X": 0.6099854707717896,
#                         "Y": 0.3986069858074188
#                     }
#                 ],
#                 "Pose": {
#                     "Roll": 1.4495017528533936,
#                     "Yaw": -6.403176307678223,
#                     "Pitch": -0.1564931571483612
#                 },
#                 "Quality": {
#                     "Brightness": 91.34667205810547,
#                     "Sharpness": 20.927310943603516
#                 },
#                 "Confidence": 99.9622802734375
#             }
#         }
#     ],
#     "FaceModelVersion": "7.0",
#     "UnindexedFaces": [],
#     "ResponseMetadata": {
#         "RequestId": "5c9bb6f0-72c3-468a-b9e9-cba9c3932991",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "x-amzn-requestid": "5c9bb6f0-72c3-468a-b9e9-cba9c3932991",
#             "content-type": "application/x-amz-json-1.1",
#             "content-length": "4752",
#             "date": "Fri, 06 Mar 2026 08:18:43 GMT"
#         },
#         "RetryAttempts": 0
#     }
# }

# %% [markdown]
# ## 見つかった顔の部分だけの画像を作る

# %%
# 入力画像のファイルを読み込む
image_in = Image.open(file_in)

# 画像サイズを取得
w, h = image_in.size

# Imageオブジェクトを生成
image_out = Image.new('RGB', (w, h), (200, 200, 200))


# FaceRecords から全顔の BoundingBox を使って切り出し＆貼り付け
face_records = result.get('FaceRecords', [])
if not face_records:
    print("顔が検出・登録されませんでした。")
else:
    for rec in face_records:
        box = rec['FaceDetail']['BoundingBox']  # ← index_faces ではここから取る
        left   = int(box['Left']   * w)
        top    = int(box['Top']    * h)
        right  = left + int(box['Width']  * w)
        bottom = top  + int(box['Height'] * h)

        # 画像境界でクリップ（安全策）
        left   = max(0, min(left,   w-1))
        top    = max(0, min(top,    h-1))
        right  = max(left+1, min(right,  w))
        bottom = max(top+1,  min(bottom, h))

        # 入力画像から顔領域を切り出して、そのまま同位置に貼り付け
        face_crop = image_in.crop((left, top, right, bottom))
        image_out.paste(face_crop, (left, top))

# 保存・表示
image_out.save(file_out)
image_out.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x670>

# %% [markdown]
# # コレクションの削除

# %%
result = rekognition.delete_collection(CollectionId=collection_id)
print(json.dumps(result, indent=4))
# Out:
# {
#     "StatusCode": 200,
#     "ResponseMetadata": {
#         "RequestId": "7f95c57a-8133-4c19-94f9-a8e9ea7c483a",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "x-amzn-requestid": "7f95c57a-8133-4c19-94f9-a8e9ea7c483a",
#             "content-type": "application/x-amz-json-1.1",
#             "content-length": "18",
#             "date": "Fri, 06 Mar 2026 08:25:05 GMT"
#         },
#         "RetryAttempts": 0
#     }
# }
